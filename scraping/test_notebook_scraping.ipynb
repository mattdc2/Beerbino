# %%
import numpy as np
import pandas as pd
import requests
from bs4 import BeautifulSoup
from urllib.request import urlopen

# %%
df_beer = pd.DataFrame(columns=["link_photo", "name", "brand", "price", "type"])
index = 0
page = 1

# %%
url = "https://www.bieres.com/10-bieres#"
html = urlopen(url).read().decode("utf-8")
soup = BeautifulSoup(html, features="lxml")
divs_beer = soup.find_all("div", {"class": "item-product product_per_3 col-xs-12 col-sm-6 col-md-6 col-lg-4 col-xl-4"})

# %%
len(divs_beer)
# Out:
# 60

# %%
divs_beer
# Out:
# [<div class="item-product product_per_3 col-xs-12 col-sm-6 col-md-6 col-lg-4 col-xl-4"> <!-- style products default --> <article class="style_product_default product-miniature js-product-miniature item_in" data-id-product="1133" data-id-product-attribute="0"> <div class="img_block"> <a class="thumbnail product-thumbnail" href="https://www.bieres.com/bieres/1133-clem-s-summer-wheat.html"> <img alt="Acheter bière Clem's summer wheat" class="first-image uitlazyload" data-full-size-image-url="https://www.bieres.com/2412-flux_facebook/clem-s-summer-wheat.jpg" data-height="360" data-original="https://www.bieres.com/2412-home_default/clem-s-summer-wheat.jpg" data-src="" data-width="360" height="200px" src="/modules/ultimateimagetool/views/img/blank.png" width="200px"/> </a> <ul class="product-flag"> </ul> <ul class="add_to_wish_list"> <li> <a class="addToWishlist wishlistProd_1133" data-rel="1133" href="#" onclick="WishlistCart('wishlist_block_list', 'add', '1133', false, 1); return false;" title="Ajouter aux favoris"> 		Ajouter aux favoris 	</a> </li> </ul> </div> <div class="product_desc"> <div class="inner_desc"> <div class="title_3"><a class="product_name" href="https://www.bieres.com/bieres/1133-clem-s-summer-wheat.html" title="Clem's summer wheat">Clem's summer wheat</a></div> <div class="manufacturer"><a href="https://www.bieres.com/brasserie/101-deck-donohue">Deck &amp; Donohue</a></div> <div class="product_features"> <span>33cl</span> |					<span>Alc. 4,5 %</span> |					<span>France</span> </div> <div class="product-price-and-shipping"> <span class="sr-only">Prix</span> <span class="price_from">A partir de </span><span class="price">2,98 €</span> </div> </div> <div class="variant-links"> </div> </div> <a href="https://www.bieres.com/bieres/1133-clem-s-summer-wheat.html"> <div class="beer_feature"> <span>Fruitée</span> </div> </a> <ul class="add-to-links"> <li class="cart"> <div class="product-add-to-cart"> <form action="https://www.bieres.com/panier" class="add-to-cart-or-refresh" method="post"> <input name="token" type="hidden" value="4f8e4e0a424365cce55862cc8097928d"/> <input class="product_page_product_id" name="id_product" type="hidden" value="1133"/> <input name="qty" type="hidden" value="1"/> <button class="button ajax_add_to_cart_button add-to-cart btn-default" data-button-action="add-to-cart" type="submit"> <i class="fa fa-beer"></i> Ajouter au panier    </button> </form> </div> </li> </ul> </article> <!-- end style products default --> <!-- style products default type 1 --> <!-- end style products default type 3 --> </div>,
#  <div class="item-product product_per_3 col-xs-12 col-sm-6 col-md-6 col-lg-4 col-xl-4"> <!-- style products default --> <article class="style_product_default product-miniature js-product-miniature item_in" data-id-product="936" data-id-product-attribute="0"> <div class="img_block"> <a class="thumbnail product-thumbnail" href="https://www.bieres.com/bieres/936-non-essentiel.html"> <img alt="Acheter bière Non-Essentiel" class="first-image uitlazyload" data-full-size-image-url="https://www.bieres.com/1950-flux_facebook/non-essentiel.jpg" data-height="360" data-original="https://www.bieres.com/1950-home_default/non-essentiel.jpg" data-src="" data-width="360" height="200px" src="/modules/ultimateimagetool/views/img/blank.png" width="200px"/> </a> <ul class="product-flag"> </ul> <ul class="add_to_wish_list"> <li> <a class="addToWishlist wishlistProd_936" data-rel="936" href="#" onclick="WishlistCart('wishlist_block_list', 'add', '936', false, 1); return false;" title="Ajouter aux favoris"> 		Ajouter aux favoris 	</a> </li> </ul> </div> <div class="product_desc"> <div class="inner_desc"> <div class="title_3"><a class="product_name" href="https://www.bieres.com/bieres/936-non-essentiel.html" title="Non-Essentiel">Non-Essentiel</a></div> <div class="manufacturer"><a href="https://www.bieres.com/brasserie/17-effet-papillon">Effet Papillon</a></div> <div class="product_features"> <span>IPA</span> |					<span>33cl</span> |					<span>Alc. 6%</span> |					<span>France</span> </div> <div class="product-price-and-shipping"> <span class="sr-only">Prix</span> <span class="price_from">A partir de </span><span class="price">3,72 €</span> </div> </div> <div class="variant-links"> </div> </div> <a href="https://www.bieres.com/bieres/936-non-essentiel.html"> <div class="beer_feature"> <span>Florale</span> </div> </a> <ul class="add-to-links"> <li class="cart"> <div class="product-add-to-cart"> <form action="https://www.bieres.com/panier" class="add-to-cart-or-refresh" method="post"> <input name="token" type="hidden" value="4f8e4e0a424365cce55862cc8097928d"/> <input class="product_page_product_id" name="id_product" type="hidden" value="936"/> <input name="qty" type="hidden" value="1"/> <button class="button ajax_add_to_cart_button add-to-cart btn-default" data-button-action="add-to-cart" type="submit"> <i class="fa fa-beer"></i> Ajouter au panier    </button> </form> </div> </li> </ul> </article> <!-- end style products default --> <!-- style products default type 1 --> <!-- end style products default type 3 --> </div>,
#  <div class="item-product product_per_3 col-xs-12 col-sm-6 col-md-6 col-lg-4 col-xl-4"> <!-- style products default --> <article class="style_product_default product-miniature js-product-miniature item_in" data-id-product="948" data-id-product-attribute="0"> <div class="img_block"> <a class="thumbnail product-thumbnail" href="https://www.bieres.com/bieres/948-ipa.html"> <img alt="Acheter bière IPA" class="first-image uitlazyload" data-full-size-image-url="https://www.bieres.com/1983-flux_facebook/ipa.jpg" data-height="360" data-original="https://www.bieres.com/1983-home_default/ipa.jpg" data-src="" data-width="360" height="200px" src="/modules/ultimateimagetool/views/img/blank.png" width="200px"/> </a> <ul class="product-flag"> </ul> <ul class="add_to_wish_list"> <li> <a class="addToWishlist wishlistProd_948" data-rel="948" href="#" onclick="WishlistCart('wishlist_block_list', 'add', '948', false, 1); return false;" title="Ajouter aux favoris"> 		Ajouter aux favoris 	</a> </li> </ul> </div> <div class="product_desc"> <div class="inner_desc"> <div class="title_3"><a class="product_name" href="https://www.bieres.com/bieres/948-ipa.html" title="IPA">IPA</a></div> <div class="manufacturer"><a href="https://www.bieres.com/brasserie/43-galibot">Galibot</a></div> <div class="product_features"> <span>IPA</span> |					<span>33cl</span> |					<span>Alc. 6%</span> |					<span>France</span> </div> <div class="product-price-and-shipping"> <span class="sr-only">Prix</span> <span class="price_from">A partir de </span><span class="price">3,44 €</span> </div> </div> <div class="variant-links"> </div> </div> <a href="https://www.bieres.com/bieres/948-ipa.html"> <div class="beer_feature"> <span>Amère</span> </div> </a> <ul class="add-to-links"> <li class="cart"> <div class="product-add-to-cart"> <form action="https://www.bieres.com/panier" class="add-to-cart-or-refresh" method="post"> <input name="token" type="hidden" value="4f8e4e0a424365cce55862cc8097928d"/> <input class="product_page_product_id" name="id_product" type="hidden" value="948"/> <input name="qty" type="hidden" value="1"/> <button class="button ajax_add_to_cart_button add-to-cart btn-default" data-button-action="add-to-cart" type="submit"> <i class="fa fa-beer"></i> Ajouter au panier    </button> </form> </div> </li> </ul> </article> <!-- end style products default --> <!-- style products default type 1 --> <!-- end style products default type 3 --> </div>,
#  <div class="item-product product_per_3 col-xs-12 col-sm-6 col-md-6 col-lg-4 col-xl-4"> <!-- style products default --> <article class="style_product_default product-miniature js-product-miniature item_in" data-id-product="945" data-id-product-attribute="0"> <div class="img_block"> <a class="thumbnail product-thumbnail" href="https://www.bieres.com/bieres/945-sabro-laser.html"> <img alt="Acheter bière Sabro Laser" class="first-image uitlazyload" data-full-size-image-url="https://www.bieres.com/1974-flux_facebook/sabro-laser.jpg" data-height="360" data-original="https://www.bieres.com/1974-home_default/sabro-laser.jpg" data-src="" data-width="360" height="200px" src="/modules/ultimateimagetool/views/img/blank.png" width="200px"/> </a> <ul class="product-flag"> </ul> <ul class="add_to_wish_list"> <li> <a class="addToWishlist wishlistProd_945" data-rel="945" href="#" onclick="WishlistCart('wishlist_block_list', 'add', '945', false, 1); return false;" title="Ajouter aux favoris"> 		Ajouter aux favoris 	</a> </li> </ul> </div> <div class="product_desc"> <div class="inner_desc"> <div class="title_3"><a class="product_name" href="https://www.bieres.com/bieres/945-sabro-laser.html" title="Sabro Laser">Sabro Laser</a></div> <div class="manufacturer"><a href="https://www.bieres.com/brasserie/29-pleine-lune">Pleine Lune</a></div> <div class="product_features"> <span>IPA</span> |					<span>33cl</span> |					<span>Alc. 6</span> |					<span>France</span> </div> <div class="product-price-and-shipping"> <span class="sr-only">Prix</span> <span class="price_from">A partir de </span><span class="price">3,35 €</span> </div> </div> <div class="variant-links"> </div> </div> <a href="https://www.bieres.com/bieres/945-sabro-laser.html"> <div class="beer_feature"> <span>Torréfiée</span> </div> </a> <ul class="add-to-links"> <li class="cart"> <span class="ajax_add_to_cart_button disabled" title="Out of stock"><i class="fa fa-beer"></i> Ajouter au panier</span> </li> </ul> </article> <!-- end style products default --> <!-- style products default type 1 --> <!-- end style products default type 3 --> </div>,
#  <div class="item-product product_per_3 col-xs-12 col-sm-6 col-md-6 col-lg-4 col-xl-4"> <!-- style products default --> <article class="style_product_default product-miniature js-product-miniature item_in" data-id-product="953" data-id-product-attribute="0"> <div class="img_block"> <a class="thumbnail product-thumbnail" href="https://www.bieres.com/bieres/953-andreas.html"> <img alt="Acheter bière Andreas" class="first-image uitlazyload" data-full-size-image-url="https://www.bieres.com/2011-flux_facebook/andreas.jpg" data-height="360" data-original="https://www.bieres.com/2011-home_default/andreas.jpg" data-src="" data-width="360" height="200px" src="/modules/ultimateimagetool/views/img/blank.png" width="200px"/> </a> <ul class="product-flag"> </ul> <ul class="add_to_wish_list"> <li> <a class="addToWishlist wishlistProd_953" data-rel="953" href="#" onclick="WishlistCart('wishlist_block_list', 'add', '953', false, 1); return false;" title="Ajouter aux favoris"> 		Ajouter aux favoris 	</a> </li> </ul> </div> <div class="product_desc"> <div class="inner_desc"> <div class="title_3"><a class="product_name" href="https://www.bieres.com/bieres/953-andreas.html" title="Andreas">Andreas</a></div> <div class="manufacturer"><a href="https://www.bieres.com/brasserie/55-frontaal">Frontaal</a></div> <div class="product_features"> <span>Ale</span> |					<span>33cl</span> |					<span>Alc. 8.50 %</span> |					<span>Pays-bas</span> </div> <div id="pListRate"><div class="steavisgarantisStar" style="margin: auto;display: inline-block;"><span></span><span class="note animate" style="width:100%"></span></div><span id="pListReviewCount" style="vertical-align: top;line-height: 32px;margin-left: 7px;">(1 avis)</span></div> <div class="product-price-and-shipping"> <span class="sr-only">Prix</span> <span class="price_from">A partir de </span><span class="price">4,65 €</span> </div> </div> <div class="variant-links"> </div> </div> <a href="https://www.bieres.com/bieres/953-andreas.html"> <div class="beer_feature"> <span>Maltée</span> </div> </a> <ul class="add-to-links"> <li class="cart"> <div class="product-add-to-cart"> <form action="https://www.bieres.com/panier" class="add-to-cart-or-refresh" method="post"> <input name="token" type="hidden" value="4f8e4e0a424365cce55862cc8097928d"/> <input class="product_page_product_id" name="id_product" type="hidden" value="953"/> <input name="qty" type="hidden" value="1"/> <button class="button ajax_add_to_cart_button add-to-cart btn-default" data-button-action="add-to-cart" type="submit"> <i class="fa fa-beer"></i> Ajouter au panier    </button> </form> </div> </li> </ul> </article> <!-- end style products default --> <!-- style products default type 1 --> <!-- end style products default type 3 --> </div>,
#  <div class="item-product product_per_3 col-xs-12 col-sm-6 col-md-6 col-lg-4 col-xl-4"> <!-- style products default --> <article class="style_product_default product-miniature js-product-miniature item_in" data-id-product="956" data-id-product-attribute="0"> <div class="img_block"> <a class="thumbnail product-thumbnail" href="https://www.bieres.com/bieres/956-bulldog.html"> <img alt="Acheter bière Bulldog" class="first-image uitlazyload" data-full-size-image-url="https://www.bieres.com/2014-flux_facebook/bulldog.jpg" data-height="360" data-original="https://www.bieres.com/2014-home_default/bulldog.jpg" data-src="" data-width="360" height="200px" src="/modules/ultimateimagetool/views/img/blank.png" width="200px"/> </a> <ul class="product-flag"> </ul> <ul class="add_to_wish_list"> <li> <a class="addToWishlist wishlistProd_956" data-rel="956" href="#" onclick="WishlistCart('wishlist_block_list', 'add', '956', false, 1); return false;" title="Ajouter aux favoris"> 		Ajouter aux favoris 	</a> </li> </ul> </div> <div class="product_desc"> <div class="inner_desc"> <div class="title_3"><a class="product_name" href="https://www.bieres.com/bieres/956-bulldog.html" title="Bulldog">Bulldog</a></div> <div class="manufacturer"><a href="https://www.bieres.com/brasserie/55-frontaal">Frontaal</a></div> <div class="product_features"> <span>IPA</span> |					<span>33cl</span> |					<span>Alc. 6 %</span> |					<span>Pays-bas</span> </div> <div id="pListRate"><div class="steavisgarantisStar" style="margin: auto;display: inline-block;"><span></span><span class="note animate" style="width:80%"></span></div><span id="pListReviewCount" style="vertical-align: top;line-height: 32px;margin-left: 7px;">(1 avis)</span></div> <div class="product-price-and-shipping"> <span class="sr-only">Prix</span> <span class="price_from">A partir de </span><span class="price">3,63 €</span> </div> </div> <div class="variant-links"> </div> </div> <a href="https://www.bieres.com/bieres/956-bulldog.html"> <div class="beer_feature"> <span>Amère</span> </div> </a> <ul class="add-to-links"> <li class="cart"> <span class="ajax_add_to_cart_button disabled" title="Out of stock"><i class="fa fa-beer"></i> Ajouter au panier</span> </li> </ul> </article> <!-- end style products default --> <!-- style products default type 1 --> <!-- end style products default type 3 --> </div>,
#  <div class="item-product product_per_3 col-xs-12 col-sm-6 col-md-6 col-lg-4 col-xl-4"> <!-- style products default --> <article class="style_product_default product-miniature js-product-miniature item_in" data-id-product="959" data-id-product-attribute="0"> <div class="img_block"> <a class="thumbnail product-thumbnail" href="https://www.bieres.com/bieres/959-freehand.html"> <img alt="Acheter bière Freehand" class="first-image uitlazyload" data-full-size-image-url="https://www.bieres.com/2023-flux_facebook/freehand.jpg" data-height="360" data-original="https://www.bieres.com/2023-home_default/freehand.jpg" data-src="" data-width="360" height="200px" src="/modules/ultimateimagetool/views/img/blank.png" width="200px"/> </a> <ul class="product-flag"> </ul> <ul class="add_to_wish_list"> <li> <a class="addToWishlist wishlistProd_959" data-rel="959" href="#" onclick="WishlistCart('wishlist_block_list', 'add', '959', false, 1); return false;" title="Ajouter aux favoris"> 		Ajouter aux favoris 	</a> </li> </ul> </div> <div class="product_desc"> <div class="inner_desc"> <div class="title_3"><a class="product_name" href="https://www.bieres.com/bieres/959-freehand.html" title="Freehand">Freehand</a></div> <div class="manufacturer"><a href="https://www.bieres.com/brasserie/55-frontaal">Frontaal</a></div> <div class="product_features"> <span>Ale</span> |					<span>33cl</span> |					<span>Alc. 6.30 %</span> |					<span>Pays-bas</span> </div> <div class="product-price-and-shipping"> <span class="sr-only">Prix</span> <span class="price_from">A partir de </span><span class="price">3,53 €</span> </div> </div> <div class="variant-links"> </div> </div> <a href="https://www.bieres.com/bieres/959-freehand.html"> <div class="beer_feature"> <span>Florale</span> </div> </a> <ul class="add-to-links"> <li class="cart"> <span class="ajax_add_to_cart_button disabled" title="Out of stock"><i class="fa fa-beer"></i> Ajouter au panier</span> </li> </ul> </article> <!-- end style products default --> <!-- style products default type 1 --> <!-- end style products default type 3 --> </div>,
#  <div class="item-product product_per_3 col-xs-12 col-sm-6 col-md-6 col-lg-4 col-xl-4"> <!-- style products default --> <article class="style_product_default product-miniature js-product-miniature item_in" data-id-product="962" data-id-product-attribute="0"> <div class="img_block"> <a class="thumbnail product-thumbnail" href="https://www.bieres.com/bieres/962-buddy.html"> <img alt="Acheter bière Buddy" class="first-image uitlazyload" data-full-size-image-url="https://www.bieres.com/2026-flux_facebook/buddy.jpg" data-height="360" data-original="https://www.bieres.com/2026-home_default/buddy.jpg" data-src="" data-width="360" height="200px" src="/modules/ultimateimagetool/views/img/blank.png" width="200px"/> </a> <ul class="product-flag"> </ul> <ul class="add_to_wish_list"> <li> <a class="addToWishlist wishlistProd_962" data-rel="962" href="#" onclick="WishlistCart('wishlist_block_list', 'add', '962', false, 1); return false;" title="Ajouter aux favoris"> 		Ajouter aux favoris 	</a> </li> </ul> </div> <div class="product_desc"> <div class="inner_desc"> <div class="title_3"><a class="product_name" href="https://www.bieres.com/bieres/962-buddy.html" title="Buddy">Buddy</a></div> <div class="manufacturer"><a href="https://www.bieres.com/brasserie/55-frontaal">Frontaal</a></div> <div class="product_features"> <span>IPA</span> |					<span>33cl</span> |					<span>Alc. 0,50 %</span> |					<span>Pays-bas</span> </div> <div class="product-price-and-shipping"> <span class="sr-only">Prix</span> <span class="price_from">A partir de </span><span class="price">3,53 €</span> </div> </div> <div class="variant-links"> </div> </div> <a href="https://www.bieres.com/bieres/962-buddy.html"> <div class="beer_feature"> <span>Florale</span> </div> </a> <ul class="add-to-links"> <li class="cart"> <span class="ajax_add_to_cart_button disabled" title="Out of stock"><i class="fa fa-beer"></i> Ajouter au panier</span> </li> </ul> </article> <!-- end style products default --> <!-- style products default type 1 --> <!-- end style products default type 3 --> </div>,
#  <div class="item-product product_per_3 col-xs-12 col-sm-6 col-md-6 col-lg-4 col-xl-4"> <!-- style products default --> <article class="style_product_default product-miniature js-product-miniature item_in" data-id-product="73" data-id-product-attribute="0"> <div class="img_block"> <a class="thumbnail product-thumbnail" href="https://www.bieres.com/bieres/73-carte-blanche-33cl-the-piggy-brewing-company.html"> <img alt="Acheter bière Carte blanche" class="first-image uitlazyload" data-full-size-image-url="https://www.bieres.com/2043-flux_facebook/carte-blanche-33cl-the-piggy-brewing-company.jpg" data-height="360" data-original="https://www.bieres.com/2043-home_default/carte-blanche-33cl-the-piggy-brewing-company.jpg" data-src="" data-width="360" height="200px" src="/modules/ultimateimagetool/views/img/blank.png" width="200px"/> </a> <ul class="product-flag"> </ul> <ul class="add_to_wish_list"> <li> <a class="addToWishlist wishlistProd_73" data-rel="73" href="#" onclick="WishlistCart('wishlist_block_list', 'add', '73', false, 1); return false;" title="Ajouter aux favoris"> 		Ajouter aux favoris 	</a> </li> </ul> </div> <div class="product_desc"> <div class="inner_desc"> <div class="title_3"><a class="product_name" href="https://www.bieres.com/bieres/73-carte-blanche-33cl-the-piggy-brewing-company.html" title="Carte blanche">Carte blanche</a></div> <div class="product_features"> <span>Ale</span> |					<span>33cl</span> |					<span>Alc. 5%</span> |					<span>France</span> </div> <div id="pListRate"><div class="steavisgarantisStar" style="margin: auto;display: inline-block;"><span></span><span class="note animate" style="width:100%"></span></div><span id="pListReviewCount" style="vertical-align: top;line-height: 32px;margin-left: 7px;">(1 avis)</span></div> <div class="product-price-and-shipping"> <span class="sr-only">Prix</span> <span class="price">3,70 €</span> </div> </div> <div class="variant-links"> </div> </div> <a href="https://www.bieres.com/bieres/73-carte-blanche-33cl-the-piggy-brewing-company.html"> <div class="beer_feature"> <span>Florale</span> </div> </a> <ul class="add-to-links"> <li class="cart"> <div class="product-add-to-cart"> <form action="https://www.bieres.com/panier" class="add-to-cart-or-refresh" method="post"> <input name="token" type="hidden" value="4f8e4e0a424365cce55862cc8097928d"/> <input class="product_page_product_id" name="id_product" type="hidden" value="73"/> <input name="qty" type="hidden" value="1"/> <button class="button ajax_add_to_cart_button add-to-cart btn-default" data-button-action="add-to-cart" type="submit"> <i class="fa fa-beer"></i> Ajouter au panier    </button> </form> </div> </li> </ul> </article> <!-- end style products default --> <!-- style products default type 1 --> <!-- end style products default type 3 --> </div>,
#  <div class="item-product product_per_3 col-xs-12 col-sm-6 col-md-6 col-lg-4 col-xl-4"> <!-- style products default --> <article class="style_product_default product-miniature js-product-miniature item_in" data-id-product="965" data-id-product-attribute="0"> <div class="img_block"> <a class="thumbnail product-thumbnail" href="https://www.bieres.com/bieres/965-raspberry.html"> <img alt="Acheter bière Raspberry" class="first-image uitlazyload" data-full-size-image-url="https://www.bieres.com/2167-flux_facebook/raspberry.jpg" data-height="360" data-original="https://www.bieres.com/2167-home_default/raspberry.jpg" data-src="" data-width="360" height="200px" src="/modules/ultimateimagetool/views/img/blank.png" width="200px"/> </a> <ul class="product-flag"> </ul> <ul class="add_to_wish_list"> <li> <a class="addToWishlist wishlistProd_965" data-rel="965" href="#" onclick="WishlistCart('wishlist_block_list', 'add', '965', false, 1); return false;" title="Ajouter aux favoris"> 		Ajouter aux favoris 	</a> </li> </ul> </div> <div class="product_desc"> <div class="inner_desc"> <div class="title_3"><a class="product_name" href="https://www.bieres.com/bieres/965-raspberry.html" title="Raspberry">Raspberry</a></div> <div class="manufacturer"><a href="https://www.bieres.com/brasserie/107-collective-arts-brewing">Collective Arts Brewing</a></div> <div class="product_features"> <span>Sour</span> |					<span>35.5cl</span> |					<span>Alc. 5,50 %</span> |					<span>Canada</span> </div> <div class="product-price-and-shipping"> <span class="sr-only">Prix</span> <span class="price_from">A partir de </span><span class="price">3,26 €</span> </div> </div> <div class="variant-links"> </div> </div> <a href="https://www.bieres.com/bieres/965-raspberry.html"> <div class="beer_feature"> <span>Fruitée</span> </div> </a> <ul class="add-to-links"> <li class="cart"> <span class="ajax_add_to_cart_button disabled" title="Out of stock"><i class="fa fa-beer"></i> Ajouter au panier</span> </li> </ul> </article> <!-- end style products default --> <!-- style products default type 1 --> <!-- end style products default type 3 --> </div>,
#  <div class="item-product product_per_3 col-xs-12 col-sm-6 col-md-6 col-lg-4 col-xl-4"> <!-- style products default --> <article class="style_product_default product-miniature js-product-miniature item_in" data-id-product="968" data-id-product-attribute="0"> <div class="img_block"> <a class="thumbnail product-thumbnail" href="https://www.bieres.com/bieres/968-suria.html"> <img alt="Acheter bière Suria" class="first-image uitlazyload" data-full-size-image-url="https://www.bieres.com/2133-flux_facebook/suria.jpg" data-height="360" data-original="https://www.bieres.com/2133-home_default/suria.jpg" data-src="" data-width="360" height="200px" src="/modules/ultimateimagetool/views/img/blank.png" width="200px"/> </a> <ul class="product-flag"> </ul> <ul class="add_to_wish_list"> <li> <a class="addToWishlist wishlistProd_968" data-rel="968" href="#" onclick="WishlistCart('wishlist_block_list', 'add', '968', false, 1); return false;" title="Ajouter aux favoris"> 		Ajouter aux favoris 	</a> </li> </ul> </div> <div class="product_desc"> <div class="inner_desc"> <div class="title_3"><a class="product_name" href="https://www.bieres.com/bieres/968-suria.html" title="Suria">Suria</a></div> <div class="manufacturer"><a href="https://www.bieres.com/brasserie/110-la-pirata-brewing">La Pirata Brewing</a></div> <div class="product_features"> <span>Ale</span> |					<span>33cl</span> |					<span>Alc. 5 %</span> |					<span>Espagne</span> </div> <div id="pListRate"><div class="steavisgarantisStar" style="margin: auto;display: inline-block;"><span></span><span class="note animate" style="width:90%"></span></div><span id="pListReviewCount" style="vertical-align: top;line-height: 32px;margin-left: 7px;">(2 avis)</span></div> <div class="product-price-and-shipping"> <span class="sr-only">Prix</span> <span class="price_from">A partir de </span><span class="price">2,98 €</span> </div> </div> <div class="variant-links"> </div> </div> <a href="https://www.bieres.com/bieres/968-suria.html"> <div class="beer_feature"> <span>Florale</span> </div> </a> <ul class="add-to-links"> <li class="cart"> <span class="ajax_add_to_cart_button disabled" title="Out of stock"><i class="fa fa-beer"></i> Ajouter au panier</span> </li> </ul> </article> <!-- end style products default --> <!-- style products default type 1 --> <!-- end style products default type 3 --> </div>,
#  <div class="item-product product_per_3 col-xs-12 col-sm-6 col-md-6 col-lg-4 col-xl-4"> <!-- style products default --> <article class="style_product_default product-miniature js-product-miniature item_in" data-id-product="983" data-id-product-attribute="0"> <div class="img_block"> <a class="thumbnail product-thumbnail" href="https://www.bieres.com/bieres/983-american-ipa.html"> <img alt="Acheter bière American IPA" class="first-image uitlazyload" data-full-size-image-url="https://www.bieres.com/2182-flux_facebook/american-ipa.jpg" data-height="360" data-original="https://www.bieres.com/2182-home_default/american-ipa.jpg" data-src="" data-width="360" height="200px" src="/modules/ultimateimagetool/views/img/blank.png" width="200px"/> </a> <ul class="product-flag"> </ul> <ul class="add_to_wish_list"> <li> <a class="addToWishlist wishlistProd_983" data-rel="983" href="#" onclick="WishlistCart('wishlist_block_list', 'add', '983', false, 1); return false;" title="Ajouter aux favoris"> 		Ajouter aux favoris 	</a> </li> </ul> </div> <div class="product_desc"> <div class="inner_desc"> <div class="title_3"><a class="product_name" href="https://www.bieres.com/bieres/983-american-ipa.html" title="American IPA">American IPA</a></div> <div class="manufacturer"><a href="https://www.bieres.com/brasserie/122-azimut">Azimut</a></div> <div class="product_features"> <span>IPA</span> |					<span>33cl</span> |					<span>Alc. 6,5 %</span> |					<span>France</span> </div> <div class="product-price-and-shipping"> <span class="sr-only">Prix</span> <span class="price_from">A partir de </span><span class="price">3,39 €</span> </div> </div> <div class="variant-links"> </div> </div> <a href="https://www.bieres.com/bieres/983-american-ipa.html"> <div class="beer_feature"> <span>Florale</span> </div> </a> <ul class="add-to-links"> <li class="cart"> <span class="ajax_add_to_cart_button disabled" title="Out of stock"><i class="fa fa-beer"></i> Ajouter au panier</span> </li> </ul> </article> <!-- end style products default --> <!-- style products default type 1 --> <!-- end style products default type 3 --> </div>,
#  <div class="item-product product_per_3 col-xs-12 col-sm-6 col-md-6 col-lg-4 col-xl-4"> <!-- style products default --> <article class="style_product_default product-miniature js-product-miniature item_in" data-id-product="989" data-id-product-attribute="0"> <div class="img_block"> <a class="thumbnail product-thumbnail" href="https://www.bieres.com/bieres/989-saison-bio.html"> <img alt="Acheter bière Mongy Saison Bio" class="first-image uitlazyload" data-full-size-image-url="https://www.bieres.com/2088-flux_facebook/saison-bio.jpg" data-height="360" data-original="https://www.bieres.com/2088-home_default/saison-bio.jpg" data-src="" data-width="360" height="200px" src="/modules/ultimateimagetool/views/img/blank.png" width="200px"/> </a> <ul class="product-flag"> </ul> <ul class="add_to_wish_list"> <li> <a class="addToWishlist wishlistProd_989" data-rel="989" href="#" onclick="WishlistCart('wishlist_block_list', 'add', '989', false, 1); return false;" title="Ajouter aux favoris"> 		Ajouter aux favoris 	</a> </li> </ul> </div> <div class="product_desc"> <div class="inner_desc"> <div class="title_3"><a class="product_name" href="https://www.bieres.com/bieres/989-saison-bio.html" title="Mongy Saison Bio">Mongy Saison Bio</a></div> <div class="manufacturer"><a href="https://www.bieres.com/brasserie/125-cambier">Cambier</a></div> <div class="product_features"> <span>Ale</span> |					<span>33cl</span> |					<span>Alc. 5,2 %</span> |					<span>France</span> </div> <div class="product-price-and-shipping"> <span class="sr-only">Prix</span> <span class="price">3,30 €</span> </div> </div> <div class="variant-links"> </div> </div> <a href="https://www.bieres.com/bieres/989-saison-bio.html"> <div class="beer_feature"> <span>Sèche</span> </div> </a> <ul class="add-to-links"> <li class="cart"> <div class="product-add-to-cart"> <form action="https://www.bieres.com/panier" class="add-to-cart-or-refresh" method="post"> <input name="token" type="hidden" value="4f8e4e0a424365cce55862cc8097928d"/> <input class="product_page_product_id" name="id_product" type="hidden" value="989"/> <input name="qty" type="hidden" value="1"/> <button class="button ajax_add_to_cart_button add-to-cart btn-default" data-button-action="add-to-cart" type="submit"> <i class="fa fa-beer"></i> Ajouter au panier    </button> </form> </div> </li> </ul> </article> <!-- end style products default --> <!-- style products default type 1 --> <!-- end style products default type 3 --> </div>,
#  <div class="item-product product_per_3 col-xs-12 col-sm-6 col-md-6 col-lg-4 col-xl-4"> <!-- style products default --> <article class="style_product_default product-miniature js-product-miniature item_in" data-id-product="1019" data-id-product-attribute="0"> <div class="img_block"> <a class="thumbnail product-thumbnail" href="https://www.bieres.com/bieres/1019-ginger-beer.html"> <img alt="Acheter bière Ginger Beer" class="first-image uitlazyload" data-full-size-image-url="https://www.bieres.com/2061-flux_facebook/ginger-beer.jpg" data-height="360" data-original="https://www.bieres.com/2061-home_default/ginger-beer.jpg" data-src="" data-width="360" height="200px" src="/modules/ultimateimagetool/views/img/blank.png" width="200px"/> </a> <ul class="product-flag"> </ul> <ul class="add_to_wish_list"> <li> <a class="addToWishlist wishlistProd_1019" data-rel="1019" href="#" onclick="WishlistCart('wishlist_block_list', 'add', '1019', false, 1); return false;" title="Ajouter aux favoris"> 		Ajouter aux favoris 	</a> </li> </ul> </div> <div class="product_desc"> <div class="inner_desc"> <div class="title_3"><a class="product_name" href="https://www.bieres.com/bieres/1019-ginger-beer.html" title="Ginger Beer">Ginger Beer</a></div> <div class="manufacturer"><a href="https://www.bieres.com/brasserie/134-brasserie-gingeur">Brasserie Gingeur</a></div> <div class="product_features"> <span>Ginger beer</span> |					<span>33cl</span> |										<span>France</span> </div> <div class="product-price-and-shipping"> <span class="sr-only">Prix</span> <span class="price_from">A partir de </span><span class="price">2,98 €</span> </div> </div> <div class="variant-links"> </div> </div> <a href="https://www.bieres.com/bieres/1019-ginger-beer.html"> <div class="beer_feature"> <span>Epicée</span> </div> </a> <ul class="add-to-links"> <li class="cart"> <div class="product-add-to-cart"> <form action="https://www.bieres.com/panier" class="add-to-cart-or-refresh" method="post"> <input name="token" type="hidden" value="4f8e4e0a424365cce55862cc8097928d"/> <input class="product_page_product_id" name="id_product" type="hidden" value="1019"/> <input name="qty" type="hidden" value="1"/> <button class="button ajax_add_to_cart_button add-to-cart btn-default" data-button-action="add-to-cart" type="submit"> <i class="fa fa-beer"></i> Ajouter au panier    </button> </form> </div> </li> </ul> </article> <!-- end style products default --> <!-- style products default type 1 --> <!-- end style products default type 3 --> </div>,
#  <div class="item-product product_per_3 col-xs-12 col-sm-6 col-md-6 col-lg-4 col-xl-4"> <!-- style products default --> <article class="style_product_default product-miniature js-product-miniature item_in" data-id-product="928" data-id-product-attribute="0"> <div class="img_block"> <a class="thumbnail product-thumbnail" href="https://www.bieres.com/bieres/928-oats-on-oats-on-oats.html"> <img alt="Acheter bière Oats on Oats on Oats" class="first-image uitlazyload" data-full-size-image-url="https://www.bieres.com/1864-flux_facebook/oats-on-oats-on-oats.jpg" data-height="360" data-original="https://www.bieres.com/1864-home_default/oats-on-oats-on-oats.jpg" data-src="" data-width="360" height="200px" src="/modules/ultimateimagetool/views/img/blank.png" width="200px"/> </a> <ul class="product-flag"> </ul> <ul class="add_to_wish_list"> <li> <a class="addToWishlist wishlistProd_928" data-rel="928" href="#" onclick="WishlistCart('wishlist_block_list', 'add', '928', false, 1); return false;" title="Ajouter aux favoris"> 		Ajouter aux favoris 	</a> </li> </ul> </div> <div class="product_desc"> <div class="inner_desc"> <div class="title_3"><a class="product_name" href="https://www.bieres.com/bieres/928-oats-on-oats-on-oats.html" title="Oats on Oats on Oats">Oats on Oats on Oats</a></div> <div class="manufacturer"><a href="https://www.bieres.com/brasserie/64-siren-craft-brew">Siren Craft Brew</a></div> <div class="product_features"> <span>IPA</span> |					<span>44cl</span> |					<span>Alc. 8 %</span> |					<span>Angleterre</span> </div> <div id="pListRate"><div class="steavisgarantisStar" style="margin: auto;display: inline-block;"><span></span><span class="note animate" style="width:100%"></span></div><span id="pListReviewCount" style="vertical-align: top;line-height: 32px;margin-left: 7px;">(1 avis)</span></div> <div class="product-price-and-shipping"> <span class="sr-only">Prix de base</span> <span class="regular-price">6,60 €</span> <span class="sr-only">Prix</span> <span class="price_from">A partir de </span><span class="price price-sale">4,62 €</span> <span class="discount-percentage discount-product">-30%</span> </div> </div> <div class="variant-links"> </div> </div> <a href="https://www.bieres.com/bieres/928-oats-on-oats-on-oats.html"> <div class="beer_feature"> <span>Amère</span> <span>Florale</span> </div> </a> <ul class="add-to-links"> <li class="cart"> <span class="ajax_add_to_cart_button disabled" title="Out of stock"><i class="fa fa-beer"></i> Ajouter au panier</span> </li> </ul> </article> <!-- end style products default --> <!-- style products default type 1 --> <!-- end style products default type 3 --> </div>,
#  <div class="item-product product_per_3 col-xs-12 col-sm-6 col-md-6 col-lg-4 col-xl-4"> <!-- style products default --> <article class="style_product_default product-miniature js-product-miniature item_in" data-id-product="1016" data-id-product-attribute="0"> <div class="img_block"> <a class="thumbnail product-thumbnail" href="https://www.bieres.com/bieres/1016-stains.html"> <img alt="Acheter bière Stains Mosaic Galaxy Pale Ale" class="first-image uitlazyload" data-full-size-image-url="https://www.bieres.com/2176-flux_facebook/stains.jpg" data-height="360" data-original="https://www.bieres.com/2176-home_default/stains.jpg" data-src="" data-width="360" height="200px" src="/modules/ultimateimagetool/views/img/blank.png" width="200px"/> </a> <ul class="product-flag"> </ul> <ul class="add_to_wish_list"> <li> <a class="addToWishlist wishlistProd_1016" data-rel="1016" href="#" onclick="WishlistCart('wishlist_block_list', 'add', '1016', false, 1); return false;" title="Ajouter aux favoris"> 		Ajouter aux favoris 	</a> </li> </ul> </div> <div class="product_desc"> <div class="inner_desc"> <div class="title_3"><a class="product_name" href="https://www.bieres.com/bieres/1016-stains.html" title="Stains Mosaic Galaxy Pale Ale">Stains Mosaic Galaxy Pale Ale</a></div> <div class="manufacturer"><a href="https://www.bieres.com/brasserie/128-omnipollo">Omnipollo</a></div> <div class="product_features"> <span>Ale</span> |					<span>33cl</span> |					<span>Alc. 5,5 %</span> |					<span>Suède</span> </div> <div class="product-price-and-shipping"> <span class="sr-only">Prix</span> <span class="price_from">A partir de </span><span class="price">3,58 €</span> </div> </div> <div class="variant-links"> </div> </div> <a href="https://www.bieres.com/bieres/1016-stains.html"> <div class="beer_feature"> <span>Maltée</span> </div> </a> <ul class="add-to-links"> <li class="cart"> <div class="product-add-to-cart"> <form action="https://www.bieres.com/panier" class="add-to-cart-or-refresh" method="post"> <input name="token" type="hidden" value="4f8e4e0a424365cce55862cc8097928d"/> <input class="product_page_product_id" name="id_product" type="hidden" value="1016"/> <input name="qty" type="hidden" value="1"/> <button class="button ajax_add_to_cart_button add-to-cart btn-default" data-button-action="add-to-cart" type="submit"> <i class="fa fa-beer"></i> Ajouter au panier    </button> </form> </div> </li> </ul> </article> <!-- end style products default --> <!-- style products default type 1 --> <!-- end style products default type 3 --> </div>,
#  <div class="item-product product_per_3 col-xs-12 col-sm-6 col-md-6 col-lg-4 col-xl-4"> <!-- style products default --> <article class="style_product_default product-miniature js-product-miniature item_in" data-id-product="1013" data-id-product-attribute="0"> <div class="img_block"> <a class="thumbnail product-thumbnail" href="https://www.bieres.com/bieres/1013-spirals-galaxy-citra.html"> <img alt="Acheter bière Spirals Galaxy Citra" class="first-image uitlazyload" data-full-size-image-url="https://www.bieres.com/2173-flux_facebook/spirals-galaxy-citra.jpg" data-height="360" data-original="https://www.bieres.com/2173-home_default/spirals-galaxy-citra.jpg" data-src="" data-width="360" height="200px" src="/modules/ultimateimagetool/views/img/blank.png" width="200px"/> </a> <ul class="product-flag"> </ul> <ul class="add_to_wish_list"> <li> <a class="addToWishlist wishlistProd_1013" data-rel="1013" href="#" onclick="WishlistCart('wishlist_block_list', 'add', '1013', false, 1); return false;" title="Ajouter aux favoris"> 		Ajouter aux favoris 	</a> </li> </ul> </div> <div class="product_desc"> <div class="inner_desc"> <div class="title_3"><a class="product_name" href="https://www.bieres.com/bieres/1013-spirals-galaxy-citra.html" title="Spirals Galaxy Citra">Spirals Galaxy Citra</a></div> <div class="manufacturer"><a href="https://www.bieres.com/brasserie/128-omnipollo">Omnipollo</a></div> <div class="product_features"> <span>Ale</span> |					<span>33cl</span> |					<span>Alc. 5,3 %</span> |					<span>Suède</span> </div> <div class="product-price-and-shipping"> <span class="sr-only">Prix</span> <span class="price_from">A partir de </span><span class="price">2,58 €</span> </div> </div> <div class="variant-links"> </div> </div> <a href="https://www.bieres.com/bieres/1013-spirals-galaxy-citra.html"> <div class="beer_feature"> <span>Florale</span> </div> </a> <ul class="add-to-links"> <li class="cart"> <span class="ajax_add_to_cart_button disabled" title="Out of stock"><i class="fa fa-beer"></i> Ajouter au panier</span> </li> </ul> </article> <!-- end style products default --> <!-- style products default type 1 --> <!-- end style products default type 3 --> </div>,
#  <div class="item-product product_per_3 col-xs-12 col-sm-6 col-md-6 col-lg-4 col-xl-4"> <!-- style products default --> <article class="style_product_default product-miniature js-product-miniature item_in" data-id-product="1010" data-id-product-attribute="0"> <div class="img_block"> <a class="thumbnail product-thumbnail" href="https://www.bieres.com/bieres/1010-nuit-de-goguette.html"> <img alt="Acheter bière Nuit de Goguette" class="first-image uitlazyload" data-full-size-image-url="https://www.bieres.com/2058-flux_facebook/nuit-de-goguette.jpg" data-height="360" data-original="https://www.bieres.com/2058-home_default/nuit-de-goguette.jpg" data-src="" data-width="360" height="200px" src="/modules/ultimateimagetool/views/img/blank.png" width="200px"/> </a> <ul class="product-flag"> </ul> <ul class="add_to_wish_list"> <li> <a class="addToWishlist wishlistProd_1010" data-rel="1010" href="#" onclick="WishlistCart('wishlist_block_list', 'add', '1010', false, 1); return false;" title="Ajouter aux favoris"> 		Ajouter aux favoris 	</a> </li> </ul> </div> <div class="product_desc"> <div class="inner_desc"> <div class="title_3"><a class="product_name" href="https://www.bieres.com/bieres/1010-nuit-de-goguette.html" title="Nuit de Goguette">Nuit de Goguette</a></div> <div class="manufacturer"><a href="https://www.bieres.com/brasserie/131-garrigues">Garrigues</a></div> <div class="product_features"> <span>Stout</span> |					<span>33cl</span> |					<span>Alc. 3,9 %</span> |					<span>France</span> </div> <div class="product-price-and-shipping"> <span class="sr-only">Prix</span> <span class="price_from">A partir de </span><span class="price">3,16 €</span> </div> </div> <div class="variant-links"> </div> </div> <a href="https://www.bieres.com/bieres/1010-nuit-de-goguette.html"> <div class="beer_feature"> <span>Torréfiée</span> </div> </a> <ul class="add-to-links"> <li class="cart"> <div class="product-add-to-cart"> <form action="https://www.bieres.com/panier" class="add-to-cart-or-refresh" method="post"> <input name="token" type="hidden" value="4f8e4e0a424365cce55862cc8097928d"/> <input class="product_page_product_id" name="id_product" type="hidden" value="1010"/> <input name="qty" type="hidden" value="1"/> <button class="button ajax_add_to_cart_button add-to-cart btn-default" data-button-action="add-to-cart" type="submit"> <i class="fa fa-beer"></i> Ajouter au panier    </button> </form> </div> </li> </ul> </article> <!-- end style products default --> <!-- style products default type 1 --> <!-- end style products default type 3 --> </div>,
#  <div class="item-product product_per_3 col-xs-12 col-sm-6 col-md-6 col-lg-4 col-xl-4"> <!-- style products default --> <article class="style_product_default product-miniature js-product-miniature item_in" data-id-product="1007" data-id-product-attribute="0"> <div class="img_block"> <a class="thumbnail product-thumbnail" href="https://www.bieres.com/bieres/1007-ribouldingue.html"> <img alt="Acheter bière Ribouldingue" class="first-image uitlazyload" data-full-size-image-url="https://www.bieres.com/2067-flux_facebook/ribouldingue.jpg" data-height="360" data-original="https://www.bieres.com/2067-home_default/ribouldingue.jpg" data-src="" data-width="360" height="200px" src="/modules/ultimateimagetool/views/img/blank.png" width="200px"/> </a> <ul class="product-flag"> </ul> <ul class="add_to_wish_list"> <li> <a class="addToWishlist wishlistProd_1007" data-rel="1007" href="#" onclick="WishlistCart('wishlist_block_list', 'add', '1007', false, 1); return false;" title="Ajouter aux favoris"> 		Ajouter aux favoris 	</a> </li> </ul> </div> <div class="product_desc"> <div class="inner_desc"> <div class="title_3"><a class="product_name" href="https://www.bieres.com/bieres/1007-ribouldingue.html" title="Ribouldingue">Ribouldingue</a></div> <div class="manufacturer"><a href="https://www.bieres.com/brasserie/131-garrigues">Garrigues</a></div> <div class="product_features"> <span>Ale</span> |					<span>33cl</span> |					<span>Alc. 5,2 %</span> |					<span>France</span> </div> <div class="product-price-and-shipping"> <span class="sr-only">Prix</span> <span class="price_from">A partir de </span><span class="price">3,16 €</span> </div> </div> <div class="variant-links"> </div> </div> <a href="https://www.bieres.com/bieres/1007-ribouldingue.html"> <div class="beer_feature"> <span>Maltée</span> </div> </a> <ul class="add-to-links"> <li class="cart"> <span class="ajax_add_to_cart_button disabled" title="Out of stock"><i class="fa fa-beer"></i> Ajouter au panier</span> </li> </ul> </article> <!-- end style products default --> <!-- style products default type 1 --> <!-- end style products default type 3 --> </div>,
#  <div class="item-product product_per_3 col-xs-12 col-sm-6 col-md-6 col-lg-4 col-xl-4"> <!-- style products default --> <article class="style_product_default product-miniature js-product-miniature item_in" data-id-product="1004" data-id-product-attribute="0"> <div class="img_block"> <a class="thumbnail product-thumbnail" href="https://www.bieres.com/bieres/1004-pas-piquee-des-vers-framboise.html"> <img alt="Acheter bière Pas Piquée des vers Framboise" class="first-image uitlazyload" data-full-size-image-url="https://www.bieres.com/2073-flux_facebook/pas-piquee-des-vers-framboise.jpg" data-height="360" data-original="https://www.bieres.com/2073-home_default/pas-piquee-des-vers-framboise.jpg" data-src="" data-width="360" height="200px" src="/modules/ultimateimagetool/views/img/blank.png" width="200px"/> </a> <ul class="product-flag"> </ul> <ul class="add_to_wish_list"> <li> <a class="addToWishlist wishlistProd_1004" data-rel="1004" href="#" onclick="WishlistCart('wishlist_block_list', 'add', '1004', false, 1); return false;" title="Ajouter aux favoris"> 		Ajouter aux favoris 	</a> </li> </ul> </div> <div class="product_desc"> <div class="inner_desc"> <div class="title_3"><a class="product_name" href="https://www.bieres.com/bieres/1004-pas-piquee-des-vers-framboise.html" title="Pas Piquée des vers Framboise">Pas Piquée des vers Framboise</a></div> <div class="manufacturer"><a href="https://www.bieres.com/brasserie/131-garrigues">Garrigues</a></div> <div class="product_features"> <span>Sour</span> |					<span>33cl</span> |					<span>Alc. 4,6 %</span> |					<span>France</span> </div> <div class="product-price-and-shipping"> <span class="sr-only">Prix</span> <span class="price_from">A partir de </span><span class="price">3,16 €</span> </div> </div> <div class="variant-links"> </div> </div> <a href="https://www.bieres.com/bieres/1004-pas-piquee-des-vers-framboise.html"> <div class="beer_feature"> <span>Acidulée</span> </div> </a> <ul class="add-to-links"> <li class="cart"> <span class="ajax_add_to_cart_button disabled" title="Out of stock"><i class="fa fa-beer"></i> Ajouter au panier</span> </li> </ul> </article> <!-- end style products default --> <!-- style products default type 1 --> <!-- end style products default type 3 --> </div>,
# ...
#  <div class="item-product product_per_3 col-xs-12 col-sm-6 col-md-6 col-lg-4 col-xl-4"> <!-- style products default --> <article class="style_product_default product-miniature js-product-miniature item_in" data-id-product="1124" data-id-product-attribute="0"> <div class="img_block"> <a class="thumbnail product-thumbnail" href="https://www.bieres.com/bieres/1124-berliner-weisse-framboise.html"> <img alt="Acheter bière Berliner Weisse Framboise" class="first-image uitlazyload" data-full-size-image-url="https://www.bieres.com/2401-flux_facebook/berliner-weisse-framboise.jpg" data-height="360" data-original="https://www.bieres.com/2401-home_default/berliner-weisse-framboise.jpg" data-src="" data-width="360" height="200px" src="/modules/ultimateimagetool/views/img/blank.png" width="200px"/> </a> <ul class="product-flag"> </ul> <ul class="add_to_wish_list"> <li> <a class="addToWishlist wishlistProd_1124" data-rel="1124" href="#" onclick="WishlistCart('wishlist_block_list', 'add', '1124', false, 1); return false;" title="Ajouter aux favoris"> 		Ajouter aux favoris 	</a> </li> </ul> </div> <div class="product_desc"> <div class="inner_desc"> <div class="title_3"><a class="product_name" href="https://www.bieres.com/bieres/1124-berliner-weisse-framboise.html" title="Berliner Weisse Framboise">Berliner Weisse Framboise</a></div> <div class="manufacturer"><a href="https://www.bieres.com/brasserie/15-popihn">Popihn</a></div> <div class="product_features"> <span>Sour</span> |					<span>44cl</span> |					<span>Alc. 5 %</span> |					<span>France</span> </div> <div class="product-price-and-shipping"> <span class="sr-only">Prix</span> <span class="price">6,60 €</span> </div> </div> <div class="variant-links"> </div> </div> <a href="https://www.bieres.com/bieres/1124-berliner-weisse-framboise.html"> <div class="beer_feature"> <span>Fruitée</span> <span>Acidulée</span> </div> </a> <ul class="add-to-links"> <li class="cart"> <div class="product-add-to-cart"> <form action="https://www.bieres.com/panier" class="add-to-cart-or-refresh" method="post"> <input name="token" type="hidden" value="4f8e4e0a424365cce55862cc8097928d"/> <input class="product_page_product_id" name="id_product" type="hidden" value="1124"/> <input name="qty" type="hidden" value="1"/> <button class="button ajax_add_to_cart_button add-to-cart btn-default" data-button-action="add-to-cart" type="submit"> <i class="fa fa-beer"></i> Ajouter au panier    </button> </form> </div> </li> </ul> </article> <!-- end style products default --> <!-- style products default type 1 --> <!-- end style products default type 3 --> </div>,
#  <div class="item-product product_per_3 col-xs-12 col-sm-6 col-md-6 col-lg-4 col-xl-4"> <!-- style products default --> <article class="style_product_default product-miniature js-product-miniature item_in" data-id-product="1130" data-id-product-attribute="0"> <div class="img_block"> <a class="thumbnail product-thumbnail" href="https://www.bieres.com/bieres/1130-rock-paper.html"> <img alt="Acheter bière Rock Paper Season" class="first-image uitlazyload" data-full-size-image-url="https://www.bieres.com/2410-flux_facebook/rock-paper.jpg" data-height="360" data-original="https://www.bieres.com/2410-home_default/rock-paper.jpg" data-src="" data-width="360" height="200px" src="/modules/ultimateimagetool/views/img/blank.png" width="200px"/> </a> <ul class="product-flag"> </ul> <ul class="add_to_wish_list"> <li> <a class="addToWishlist wishlistProd_1130" data-rel="1130" href="#" onclick="WishlistCart('wishlist_block_list', 'add', '1130', false, 1); return false;" title="Ajouter aux favoris"> 		Ajouter aux favoris 	</a> </li> </ul> </div> <div class="product_desc"> <div class="inner_desc"> <div class="title_3"><a class="product_name" href="https://www.bieres.com/bieres/1130-rock-paper.html" title="Rock Paper Season">Rock Paper Season</a></div> <div class="manufacturer"><a href="https://www.bieres.com/brasserie/13-la-p-tite-maiz">La P'tite Maiz</a></div> <div class="product_features"> <span>Ale</span> |					<span>33cl</span> |					<span>Alc. 5,4 %</span> |					<span>France</span> </div> <div class="product-price-and-shipping"> <span class="sr-only">Prix</span> <span class="price">4,30 €</span> </div> </div> <div class="variant-links"> </div> </div> <a href="https://www.bieres.com/bieres/1130-rock-paper.html"> <div class="beer_feature"> <span>Florale</span> </div> </a> <ul class="add-to-links"> <li class="cart"> <div class="product-add-to-cart"> <form action="https://www.bieres.com/panier" class="add-to-cart-or-refresh" method="post"> <input name="token" type="hidden" value="4f8e4e0a424365cce55862cc8097928d"/> <input class="product_page_product_id" name="id_product" type="hidden" value="1130"/> <input name="qty" type="hidden" value="1"/> <button class="button ajax_add_to_cart_button add-to-cart btn-default" data-button-action="add-to-cart" type="submit"> <i class="fa fa-beer"></i> Ajouter au panier    </button> </form> </div> </li> </ul> </article> <!-- end style products default --> <!-- style products default type 1 --> <!-- end style products default type 3 --> </div>,
#  <div class="item-product product_per_3 col-xs-12 col-sm-6 col-md-6 col-lg-4 col-xl-4"> <!-- style products default --> <article class="style_product_default product-miniature js-product-miniature item_in" data-id-product="1128" data-id-product-attribute="0"> <div class="img_block"> <a class="thumbnail product-thumbnail" href="https://www.bieres.com/bieres/1128-badagaio.html"> <img alt="Acheter bière Badagaio" class="first-image uitlazyload" data-full-size-image-url="https://www.bieres.com/2395-flux_facebook/badagaio.jpg" data-height="360" data-original="https://www.bieres.com/2395-home_default/badagaio.jpg" data-src="" data-width="360" height="200px" src="/modules/ultimateimagetool/views/img/blank.png" width="200px"/> </a> <ul class="product-flag"> </ul> <ul class="add_to_wish_list"> <li> <a class="addToWishlist wishlistProd_1128" data-rel="1128" href="#" onclick="WishlistCart('wishlist_block_list', 'add', '1128', false, 1); return false;" title="Ajouter aux favoris"> 		Ajouter aux favoris 	</a> </li> </ul> </div> <div class="product_desc"> <div class="inner_desc"> <div class="title_3"><a class="product_name" href="https://www.bieres.com/bieres/1128-badagaio.html" title="Badagaio">Badagaio</a></div> <div class="manufacturer"><a href="https://www.bieres.com/brasserie/21-brussels-beer-project">Brussels Beer Project</a></div> <div class="product_features"> <span>Stout</span> |					<span>33cl</span> |					<span>Alc. 9,3 %</span> |					<span>Belgique</span> </div> <div class="product-price-and-shipping"> <span class="sr-only">Prix</span> <span class="price">4,30 €</span> </div> </div> <div class="variant-links"> </div> </div> <a href="https://www.bieres.com/bieres/1128-badagaio.html"> <div class="beer_feature"> </div> </a> <ul class="add-to-links"> <li class="cart"> <div class="product-add-to-cart"> <form action="https://www.bieres.com/panier" class="add-to-cart-or-refresh" method="post"> <input name="token" type="hidden" value="4f8e4e0a424365cce55862cc8097928d"/> <input class="product_page_product_id" name="id_product" type="hidden" value="1128"/> <input name="qty" type="hidden" value="1"/> <button class="button ajax_add_to_cart_button add-to-cart btn-default" data-button-action="add-to-cart" type="submit"> <i class="fa fa-beer"></i> Ajouter au panier    </button> </form> </div> </li> </ul> </article> <!-- end style products default --> <!-- style products default type 1 --> <!-- end style products default type 3 --> </div>,
#  <div class="item-product product_per_3 col-xs-12 col-sm-6 col-md-6 col-lg-4 col-xl-4"> <!-- style products default --> <article class="style_product_default product-miniature js-product-miniature item_in" data-id-product="800" data-id-product-attribute="0"> <div class="img_block"> <a class="thumbnail product-thumbnail" href="https://www.bieres.com/bieres/800-mission.html"> <img alt="Acheter bière Mission" class="first-image uitlazyload" data-full-size-image-url="https://www.bieres.com/1628-flux_facebook/mission.jpg" data-height="360" data-original="https://www.bieres.com/1628-home_default/mission.jpg" data-src="" data-width="360" height="200px" src="/modules/ultimateimagetool/views/img/blank.png" width="200px"/> </a> <ul class="product-flag"> </ul> <ul class="add_to_wish_list"> <li> <a class="addToWishlist wishlistProd_800" data-rel="800" href="#" onclick="WishlistCart('wishlist_block_list', 'add', '800', false, 1); return false;" title="Ajouter aux favoris"> 		Ajouter aux favoris 	</a> </li> </ul> </div> <div class="product_desc"> <div class="inner_desc"> <div class="title_3"><a class="product_name" href="https://www.bieres.com/bieres/800-mission.html" title="Mission">Mission</a></div> <div class="manufacturer"><a href="https://www.bieres.com/brasserie/101-deck-donohue">Deck &amp; Donohue</a></div> <div class="product_features"> <span>Ale</span> |					<span>33cl</span> |					<span>Alc. 4,80%</span> |					<span>France</span> </div> <div class="product-price-and-shipping"> <span class="sr-only">Prix</span> <span class="price_from">A partir de </span><span class="price">2,98 €</span> </div> </div> <div class="variant-links"> </div> </div> <a href="https://www.bieres.com/bieres/800-mission.html"> <div class="beer_feature"> <span>Maltée</span> </div> </a> <ul class="add-to-links"> <li class="cart"> <div class="product-add-to-cart"> <form action="https://www.bieres.com/panier" class="add-to-cart-or-refresh" method="post"> <input name="token" type="hidden" value="4f8e4e0a424365cce55862cc8097928d"/> <input class="product_page_product_id" name="id_product" type="hidden" value="800"/> <input name="qty" type="hidden" value="1"/> <button class="button ajax_add_to_cart_button add-to-cart btn-default" data-button-action="add-to-cart" type="submit"> <i class="fa fa-beer"></i> Ajouter au panier    </button> </form> </div> </li> </ul> </article> <!-- end style products default --> <!-- style products default type 1 --> <!-- end style products default type 3 --> </div>,
#  <div class="item-product product_per_3 col-xs-12 col-sm-6 col-md-6 col-lg-4 col-xl-4"> <!-- style products default --> <article class="style_product_default product-miniature js-product-miniature item_in" data-id-product="794" data-id-product-attribute="0"> <div class="img_block"> <a class="thumbnail product-thumbnail" href="https://www.bieres.com/bieres/794-trouble.html"> <img alt="Acheter bière Trouble" class="first-image uitlazyload" data-full-size-image-url="https://www.bieres.com/1640-flux_facebook/trouble.jpg" data-height="360" data-original="https://www.bieres.com/1640-home_default/trouble.jpg" data-src="" data-width="360" height="200px" src="/modules/ultimateimagetool/views/img/blank.png" width="200px"/> </a> <ul class="product-flag"> </ul> <ul class="add_to_wish_list"> <li> <a class="addToWishlist wishlistProd_794" data-rel="794" href="#" onclick="WishlistCart('wishlist_block_list', 'add', '794', false, 1); return false;" title="Ajouter aux favoris"> 		Ajouter aux favoris 	</a> </li> </ul> </div> <div class="product_desc"> <div class="inner_desc"> <div class="title_3"><a class="product_name" href="https://www.bieres.com/bieres/794-trouble.html" title="Trouble">Trouble</a></div> <div class="manufacturer"><a href="https://www.bieres.com/brasserie/101-deck-donohue">Deck &amp; Donohue</a></div> <div class="product_features"> <span>Ale</span> |					<span>33cl</span> |					<span>Alc. 4,80%</span> |					<span>France</span> </div> <div class="product-price-and-shipping"> <span class="sr-only">Prix</span> <span class="price_from">A partir de </span><span class="price">2,98 €</span> </div> </div> <div class="variant-links"> </div> </div> <a href="https://www.bieres.com/bieres/794-trouble.html"> <div class="beer_feature"> <span>Sèche</span> </div> </a> <ul class="add-to-links"> <li class="cart"> <div class="product-add-to-cart"> <form action="https://www.bieres.com/panier" class="add-to-cart-or-refresh" method="post"> <input name="token" type="hidden" value="4f8e4e0a424365cce55862cc8097928d"/> <input class="product_page_product_id" name="id_product" type="hidden" value="794"/> <input name="qty" type="hidden" value="1"/> <button class="button ajax_add_to_cart_button add-to-cart btn-default" data-button-action="add-to-cart" type="submit"> <i class="fa fa-beer"></i> Ajouter au panier    </button> </form> </div> </li> </ul> </article> <!-- end style products default --> <!-- style products default type 1 --> <!-- end style products default type 3 --> </div>,
#  <div class="item-product product_per_3 col-xs-12 col-sm-6 col-md-6 col-lg-4 col-xl-4"> <!-- style products default --> <article class="style_product_default product-miniature js-product-miniature item_in" data-id-product="797" data-id-product-attribute="0"> <div class="img_block"> <a class="thumbnail product-thumbnail" href="https://www.bieres.com/bieres/797-d-pilsner.html"> <img alt="Acheter bière D Pilsner" class="first-image uitlazyload" data-full-size-image-url="https://www.bieres.com/1658-flux_facebook/d-pilsner.jpg" data-height="360" data-original="https://www.bieres.com/1658-home_default/d-pilsner.jpg" data-src="" data-width="360" height="200px" src="/modules/ultimateimagetool/views/img/blank.png" width="200px"/> </a> <ul class="product-flag"> </ul> <ul class="add_to_wish_list"> <li> <a class="addToWishlist wishlistProd_797" data-rel="797" href="#" onclick="WishlistCart('wishlist_block_list', 'add', '797', false, 1); return false;" title="Ajouter aux favoris"> 		Ajouter aux favoris 	</a> </li> </ul> </div> <div class="product_desc"> <div class="inner_desc"> <div class="title_3"><a class="product_name" href="https://www.bieres.com/bieres/797-d-pilsner.html" title="D Pilsner">D Pilsner</a></div> <div class="manufacturer"><a href="https://www.bieres.com/brasserie/101-deck-donohue">Deck &amp; Donohue</a></div> <div class="product_features"> <span>Lager</span> |					<span>33cl</span> |					<span>Alc. 5 %</span> |					<span>France</span> </div> <div id="pListRate"><div class="steavisgarantisStar" style="margin: auto;display: inline-block;"><span></span><span class="note animate" style="width:100%"></span></div><span id="pListReviewCount" style="vertical-align: top;line-height: 32px;margin-left: 7px;">(4 avis)</span></div> <div class="product-price-and-shipping"> <span class="sr-only">Prix</span> <span class="price_from">A partir de </span><span class="price">2,88 €</span> </div> </div> <div class="variant-links"> </div> </div> <a href="https://www.bieres.com/bieres/797-d-pilsner.html"> <div class="beer_feature"> <span>Florale</span> </div> </a> <ul class="add-to-links"> <li class="cart"> <div class="product-add-to-cart"> <form action="https://www.bieres.com/panier" class="add-to-cart-or-refresh" method="post"> <input name="token" type="hidden" value="4f8e4e0a424365cce55862cc8097928d"/> <input class="product_page_product_id" name="id_product" type="hidden" value="797"/> <input name="qty" type="hidden" value="1"/> <button class="button ajax_add_to_cart_button add-to-cart btn-default" data-button-action="add-to-cart" type="submit"> <i class="fa fa-beer"></i> Ajouter au panier    </button> </form> </div> </li> </ul> </article> <!-- end style products default --> <!-- style products default type 1 --> <!-- end style products default type 3 --> </div>]

# %%
for i in range(len(divs_beer)):
    div_beer = divs_beer[i]
    
    # Find beer's photo link
    div_photo = div_beer.find('img', {'class' : 'first-image'})
    link_beer_photo = div_photo['data-original']
    print(link_beer_photo)
    
    # Find beer's name
    div_name = div_beer.find("a", {"class": "product_name"})
    if div_name != None :
        name = div_name.getText()
        print(name)
    
    # Find beer's brand
    div_brand = div_beer.find("div", {"class": "manufacturer"})
    if div_brand != None :
        brand = div_brand.find('a').getText()
        print(brand)
# Out:
# https://www.bieres.com/2412-home_default/clem-s-summer-wheat.jpg
# Clem's summer wheat
# Deck & Donohue
# https://www.bieres.com/1950-home_default/non-essentiel.jpg
# Non-Essentiel
# Effet Papillon
# https://www.bieres.com/1983-home_default/ipa.jpg
# IPA
# Galibot
# https://www.bieres.com/1974-home_default/sabro-laser.jpg
# Sabro Laser
# Pleine Lune
# https://www.bieres.com/2011-home_default/andreas.jpg
# Andreas
# Frontaal
# https://www.bieres.com/2014-home_default/bulldog.jpg
# Bulldog
# Frontaal
# https://www.bieres.com/2023-home_default/freehand.jpg
# Freehand
# Frontaal
# https://www.bieres.com/2026-home_default/buddy.jpg
# Buddy
# Frontaal
# https://www.bieres.com/2043-home_default/carte-blanche-33cl-the-piggy-brewing-company.jpg
# Carte blanche
# https://www.bieres.com/2167-home_default/raspberry.jpg
# Raspberry
# Collective Arts Brewing
# https://www.bieres.com/2133-home_default/suria.jpg
# Suria
# La Pirata Brewing
# https://www.bieres.com/2182-home_default/american-ipa.jpg
# American IPA
# Azimut
# https://www.bieres.com/2088-home_default/saison-bio.jpg
# Mongy Saison Bio
# Cambier
# https://www.bieres.com/2061-home_default/ginger-beer.jpg
# Ginger Beer
# Brasserie Gingeur
# https://www.bieres.com/1864-home_default/oats-on-oats-on-oats.jpg
# Oats on Oats on Oats
# Siren Craft Brew
# https://www.bieres.com/2176-home_default/stains.jpg
# Stains Mosaic Galaxy Pale Ale
# Omnipollo
# https://www.bieres.com/2173-home_default/spirals-galaxy-citra.jpg
# Spirals Galaxy Citra
# Omnipollo
# https://www.bieres.com/2058-home_default/nuit-de-goguette.jpg
# Nuit de Goguette
# Garrigues
# https://www.bieres.com/2067-home_default/ribouldingue.jpg
# Ribouldingue
# Garrigues
# https://www.bieres.com/2073-home_default/pas-piquee-des-vers-framboise.jpg
# Pas Piquée des vers Framboise
# Garrigues
# https://www.bieres.com/2082-home_default/ibex.jpg
# Ibex
# ZooBrew
# https://www.bieres.com/2152-home_default/stout-toujours.jpg
# Stout Toujours
# O'clock Brewing
# https://www.bieres.com/2094-home_default/jet-lag.jpg
# Jet Lag
# O'clock Brewing
# https://www.bieres.com/1879-home_default/world-beyond-my-window.jpg
# The World Beyond My Window
# Siren Craft Brew
# https://www.bieres.com/2137-home_default/time-out.jpg
# Time Out
# O'clock Brewing
# https://www.bieres.com/2127-home_default/mongy-ambree.jpg
# Mongy Ambrée
# Cambier
# https://www.bieres.com/2103-home_default/nector.jpg
# Nector
# Iron Brewery
# https://www.bieres.com/1906-home_default/fil-.jpg
# Fil
# Flügge
# https://www.bieres.com/2149-home_default/rye-smoked-porter.jpg
# Rye Smoked Porter
# Le Détour
# https://www.bieres.com/2121-home_default/sur-le-pouce.jpg
# Sur le Pouce
# O'clock Brewing
# https://www.bieres.com/2199-home_default/patt.jpg
# Patt
# Pühaste
# https://www.bieres.com/2208-home_default/vulin.jpg
# Vulin
# Pühaste
# https://www.bieres.com/2190-home_default/aussie-tour-pils.jpg
# Aussie Tour Pils
# Brasserie du Grand Paris
# https://www.bieres.com/2260-home_default/fuckin-regalade.jpg
# Fuckin Regalade
# Brasserie de Sulauze
# https://www.bieres.com/2254-home_default/dark-sister.jpg
# Dark Sister
# Brussels Beer Project
# https://www.bieres.com/2257-home_default/saison.jpg
# Saison
# Brasserie de Sulauze
# https://www.bieres.com/2281-home_default/briarde-stout.jpg
# Briarde Stout
# Brasserie Rabourdin
# https://www.bieres.com/2275-home_default/briarde-session.jpg
# Briarde Session
# Brasserie Rabourdin
# https://www.bieres.com/2316-home_default/gens-de-la-lune.jpg
# Gens de la lune
# Pleine Lune
# https://www.bieres.com/2345-home_default/ipa-citra-galactique-pamplemousse.jpg
# IPA Citra Galactique Pamplemousse
# Brasserie du Grand Paris
# https://www.bieres.com/2325-home_default/the-wedge.jpg
# The Wedge
# Siren Craft Brew
# https://www.bieres.com/2109-home_default/chill-out.jpg
# Chill'Out
# O'clock Brewing
# https://www.bieres.com/2333-home_default/abribus.jpg
# Abribus
# Bendorf
# https://www.bieres.com/2336-home_default/parle-a-mon-zebre.jpg
# Parle à mon zèbre
# ZooBrew
# https://www.bieres.com/1912-home_default/elsa.jpg
# Elsa
# Flügge
# https://www.bieres.com/2356-home_default/session-neipa.jpg
# Session NEIPA
# Paname Brewing Company
# https://www.bieres.com/1855-home_default/lutz.jpg
# Lutz
# Flügge
# https://www.bieres.com/2365-home_default/sour-gose.jpg
# Sour Gose
# Paname Brewing Company
# https://www.bieres.com/1891-home_default/uw.jpg
# U W
# Dry & Bitter
# https://www.bieres.com/2359-home_default/imperial-fruit-ipa.jpg
# Impérial Fruit IPA
# Paname Brewing Company
# https://www.bieres.com/2371-home_default/biere-de-ble.jpg
# Bière de blé
# La Brasserie Fondamentale
# https://www.bieres.com/2386-home_default/pale-ale.jpg
# Pale Ale
# La Brasserie Fondamentale
# https://www.bieres.com/2377-home_default/dubbel.jpg
# Dubbel
# La Brasserie Fondamentale
# https://www.bieres.com/2389-home_default/ipa.jpg
# IPA
# La Brasserie Fondamentale
# https://www.bieres.com/2401-home_default/berliner-weisse-framboise.jpg
# Berliner Weisse Framboise
# Popihn
# https://www.bieres.com/2410-home_default/rock-paper.jpg
# Rock Paper Season
# La P'tite Maiz
# https://www.bieres.com/2395-home_default/badagaio.jpg
# Badagaio
# Brussels Beer Project
# https://www.bieres.com/1628-home_default/mission.jpg
# Mission
# Deck & Donohue
# https://www.bieres.com/1640-home_default/trouble.jpg
# Trouble
# Deck & Donohue
# https://www.bieres.com/1658-home_default/d-pilsner.jpg
# D Pilsner
# Deck & Donohue
